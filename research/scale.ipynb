# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import librosa
import librosa.display
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt


import sys
import numpy
np.set_printoptions(threshold=sys.maxsize, suppress=True)

# %%
recording_file = "/Users/duongtat/Work/_skola/VMM/tmp/7d3119ed1bb6bc9e65b3ed000.wav"

# %%
from util.draw import draw_single


recording_large, sr_large = librosa.load(recording_file, sr=22_050)
recording_small, sr_small = librosa.load(recording_file, sr=11_025)

fig, axs = plt.subplots(2, 1, figsize=(16, 8))

print(sr_large, sr_small)

draw_single(
    recording_large,
    sr=sr_large,
    n_fft=2048,
    hop_length=2048 // 4,
    ylim=5000,
    fig=axs[0]
)

draw_single(
    recording_small,
    sr=sr_small,
    n_fft=2048,
    hop_length=2048 // 4,
    ylim=5000,
    fig=axs[1]
)
# Out:
# 22050 11025
